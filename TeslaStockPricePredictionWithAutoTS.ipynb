# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime
from datetime import date, timedelta

# %%
d1 = date.today().strftime("%Y-%m-%d")
end_date = d1

# %%
d2 = date.today() - timedelta(days=1080)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

# %%
df = yf.download('TSLA',
                 start= start_date,
                 end= end_date,
                 progress=False)
print(df.head())
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2020-02-24 00:00:00-05:00  55.933334  57.566666  54.813332  55.585999
# 2020-02-25 00:00:00-05:00  56.599998  57.106667  52.466667  53.327332
# 2020-02-26 00:00:00-05:00  52.166668  54.220669  51.740665  51.919998
# 2020-02-27 00:00:00-05:00  48.666668  49.318001  44.599998  45.266666
# 2020-02-28 00:00:00-05:00  41.980000  46.034668  40.768002  44.532665
#
#                            Adj Close     Volume
# Date
# 2020-02-24 00:00:00-05:00  55.585999  227883000
# 2020-02-25 00:00:00-05:00  53.327332  259357500
# 2020-02-26 00:00:00-05:00  51.919998  211282500
# 2020-02-27 00:00:00-05:00  45.266666  364158000
# 2020-02-28 00:00:00-05:00  44.532665  363343500

# %%
df.reset_index()
# Out:
#                          Date        Open        High         Low       Close  \
# 0   2020-02-24 00:00:00-05:00   55.933334   57.566666   54.813332   55.585999
# 1   2020-02-25 00:00:00-05:00   56.599998   57.106667   52.466667   53.327332
# 2   2020-02-26 00:00:00-05:00   52.166668   54.220669   51.740665   51.919998
# 3   2020-02-27 00:00:00-05:00   48.666668   49.318001   44.599998   45.266666
# 4   2020-02-28 00:00:00-05:00   41.980000   46.034668   40.768002   44.532665
# ..                        ...         ...         ...         ...         ...
# 739 2023-01-30 00:00:00-05:00  178.050003  179.770004  166.500000  166.660004
# 740 2023-01-31 00:00:00-05:00  164.570007  174.300003  162.779999  173.220001
# 741 2023-02-01 00:00:00-05:00  173.889999  183.809998  169.929993  181.410004
# 742 2023-02-02 00:00:00-05:00  187.330002  196.750000  182.610001  188.270004
# 743 2023-02-03 00:00:00-05:00  183.949997  199.000000  183.690002  189.979996
#
#       Adj Close     Volume
# 0     55.585999  227883000
# 1     53.327332  259357500
# 2     51.919998  211282500
# 3     45.266666  364158000
# 4     44.532665  363343500
# ..          ...        ...
# 739  166.660004  230878800
# 740  173.220001  196813500
# 741  181.410004  213806300
# 742  188.270004  217448300
# 743  189.979996  231684200
#
# [744 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2020-02-24 00:00:00-05:00  55.933334  57.566666  54.813332  55.585999
# 2020-02-25 00:00:00-05:00  56.599998  57.106667  52.466667  53.327332
# 2020-02-26 00:00:00-05:00  52.166668  54.220669  51.740665  51.919998
# 2020-02-27 00:00:00-05:00  48.666668  49.318001  44.599998  45.266666
# 2020-02-28 00:00:00-05:00  41.980000  46.034668  40.768002  44.532665
#
#                            Adj Close     Volume
# Date
# 2020-02-24 00:00:00-05:00  55.585999  227883000
# 2020-02-25 00:00:00-05:00  53.327332  259357500
# 2020-02-26 00:00:00-05:00  51.919998  211282500
# 2020-02-27 00:00:00-05:00  45.266666  364158000
# 2020-02-28 00:00:00-05:00  44.532665  363343500

# %%
#df.set_index('Date', inplace= True)

# %%
#df.columns = ["Date", "Open", "High", "Low", "Close", "Adj close", "Volume"]

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\TOSHIBA\Desktop\Projelerim\Tesla Stock Price Prediction\TeslaStockPricePredictionWithAutoTS.ipynb Cell 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/TOSHIBA/Desktop/Projelerim/Tesla%20Stock%20Price%20Prediction/TeslaStockPricePredictionWithAutoTS.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format= True)
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Date'

# %%
import plotly.graph_objects as go

# %%
figure = go.Figure(data = [go.Candlestick(x = df.index,
                            open = df["Open"],
                            high= df["High"],
                            low = df["Low"],
                            close = df["Close"])])
figure.update_layout(title = "Time Series Anlaysis(Candlestick Chart with buttons and slider)")

figure.update_xaxes(
                    rangeslider_visible = True,
                    rangeselector = dict(
                        buttons = list([
                            dict(count = 1, label = "1s", step = "second", stepmode = "backward"),
                            dict(count = 1, label = "1m", step = "minute", stepmode = "backward"),
                            dict(count = 1, label = "1h", step = "hour", stepmode = "backward"),
                            dict(count = 1, label = "1d", step = "day", stepmode = "backward"),
                            dict(count = 1, label = "1m", step = "month", stepmode = "backward"),
                            dict(count = 6, label = "6m", step = "month", stepmode = "backward"),
                            dict(count = 1, label = "YTD", step = "year", stepmode = "todate"),
                            dict(count = 1, label = "1y", step = "year", stepmode = "backward"),
                            dict(step = "all")
                    ])
)
)

figure.show()

# %%
from autots import AutoTS

# %%
model = AutoTS(forecast_length= 10,
               frequency= 'infer',
               ensemble= 'simple')

model = model.fit(df, date_col = 'Date', value_col = 'Close', id_col = None)
prediction = model.predict()
forecast = prediction.forecast
print(forecast)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\autots\tools\shaping.py:139, in long_to_wide(df, date_col, value_col, id_col, aggfunc)
#     137 try:
#     138     df_long[date_col] = pd.to_datetime(
# --> 139         df_long[date_col], infer_datetime_format=True
#     140     )
#     141 except Exception:
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\TOSHIBA\Desktop\Projelerim\Tesla Stock Price Prediction\TeslaStockPricePredictionWithAutoTS.ipynb Cell 16 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/TOSHIBA/Desktop/Projelerim/Tesla%20Stock%20Price%20Prediction/TeslaStockPricePredictionWithAutoTS.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> model = AutoTS(forecast_length= 10,
#       <a href='vscode-notebook-cell:/c%3A/Users/TOSHIBA/Desktop/Projelerim/Tesla%20Stock%20Price%20Prediction/TeslaStockPricePredictionWithAutoTS.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a>                frequency= 'infer',
#       <a href='vscode-notebook-cell:/c%3A/Users/TOSHIBA/Desktop/Projelerim/Tesla%20Stock%20Price%20Prediction/TeslaStockPricePredictionWithAutoTS.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a>                ensemble= 'simple')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/TOSHIBA/Desktop/Projelerim/Tesla%20Stock%20Price%20Prediction/TeslaStockPricePredictionWithAutoTS.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> model = model.fit(df, date_col = 'Date', value_col = 'Close', id_col = None)
#       <a href='vscode-notebook-cell:/c%3A/Users/TOSHIBA/Desktop/Projelerim/Tesla%20Stock%20Price%20Prediction/TeslaStockPricePredictionWithAutoTS.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> prediction = model.predict()
#       <a href='vscode-notebook-cell:/c%3A/Users/TOSHIBA/Desktop/Projelerim/Tesla%20Stock%20Price%20Prediction/TeslaStockPricePredictionWithAutoTS.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> forecast = prediction.forecast
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\autots\evaluator\auto_ts.py:735, in AutoTS.fit(self, df, date_col, value_col, id_col, future_regressor, weights, result_file, grouping_ids, validation_indexes)
#     733     df_wide = df_wide.sort_index(ascending=True)
#     734 else:
# --> 735     df_wide = long_to_wide(
#     736         df,
#     737         date_col=self.date_col,
#     738         value_col=self.value_col,
#     739         id_col=self.id_col,
#     740         aggfunc=self.aggfunc,
#     741     )
#     743 df_wide = df_cleanup(
#     744     df_wide,
#     745     frequency=self.frequency,
#    (...)
#     751     verbose=self.verbose,
#     752 )
#     754 # handle categorical data if present
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\autots\tools\shaping.py:142, in long_to_wide(df, date_col, value_col, id_col, aggfunc)
#     138     df_long[date_col] = pd.to_datetime(
#     139         df_long[date_col], infer_datetime_format=True
#     140     )
#     141 except Exception:
# --> 142     raise ValueError(
#     143         "Could not convert date to datetime format. Incorrect column name or preformat with pandas to_datetime"
#     144     )
#     146 # handle no id_col for if only one time series
#     147 if id_col in [None, 'None']:
#
# ValueError: Could not convert date to datetime format. Incorrect column name or preformat with pandas to_datetime
